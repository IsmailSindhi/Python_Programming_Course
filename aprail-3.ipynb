# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r'C:\Users\ismail\Downloads\Compressed\insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
l_enc = LabelEncoder()
df["smoker"] =  pd.DataFrame(l_enc.fit_transform(df['smoker']))

# %%
df.describe()
# Out:
#                age          bmi     children       smoker       charges  \
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918     0.204783  13270.422265
# std      14.049960     6.098187     1.205493     0.403694  12110.011237
# min      18.000000    15.960000     0.000000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000     0.000000   9382.033000
# 75%      51.000000    34.693750     2.000000     0.000000  16639.912515
# max      64.000000    53.130000     5.000000     1.000000  63770.428010
#
#         sex_female     sex_male  region_northeast  region_northwest  \
# count  1338.000000  1338.000000       1338.000000       1338.000000
# mean      0.494768     0.505232          0.242152          0.242900
# std       0.500160     0.500160          0.428546          0.428995
# ...

# %%
one_hot = OneHotEncoder(handle_unknown="ignore")
enc_df = pd.DataFrame(one_hot.fit_transform(df[["sex"]]).toarray())

# %%
dum_df = pd.get_dummies(df[["sex"]])

# %%
df = df.join(dum_df)

# %%
df
# Out:
#       age     sex     bmi  children  smoker     region      charges  \
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
#       sex_female  sex_male
# 0              1         0
# 1              0         1
# 2              0         1
# 3              0         1
# ...

# %%
dum_df = pd.get_dummies(df[["region"]])
df = df.join(dum_df)
df
# Out:
#       age     sex     bmi  children  smoker     region      charges  \
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
#       sex_female  sex_male  region_northeast  region_northwest  \
# 0              1         0                 0                 0
# ...

# %%
df.drop(["sex","region"], axis=1,inplace=True)

# %%
df
# Out:
#       age     bmi  children  smoker      charges  sex_female  sex_male  \
# 0      19  27.900         0       1  16884.92400           1         0
# 1      18  33.770         1       0   1725.55230           0         1
# 2      28  33.000         3       0   4449.46200           0         1
# 3      33  22.705         0       0  21984.47061           0         1
# 4      32  28.880         0       0   3866.85520           0         1
# ...   ...     ...       ...     ...          ...         ...       ...
# 1333   50  30.970         3       0  10600.54830           0         1
# 1334   18  31.920         0       0   2205.98080           1         0
# 1335   18  36.850         0       0   1629.83350           1         0
# 1336   21  25.800         0       0   2007.94500           1         0
# 1337   61  29.070         0       1  29141.36030           1         0
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
y = df["charges"]

# %%
X = df.drop("charges",axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=74)

# %%
X_test
# Out:
#       age     bmi  children  smoker  sex_female  sex_male  region_northeast  \
# 676    55  40.810         3       0           1         0                 0
# 217    27  23.100         0       0           0         1                 0
# 864    51  25.400         0       0           0         1                 0
# 751    21  28.975         0       0           0         1                 0
# 1106   49  29.925         0       0           1         0                 0
# ...   ...     ...       ...     ...         ...       ...               ...
# 1227   42  37.180         2       0           0         1                 0
# 491    61  25.080         0       0           1         0                 0
# 313    49  35.860         0       0           0         1                 0
# 43     37  30.800         2       0           1         0                 0
# 1080   18  21.780         2       0           0         1                 0
#
# ...

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(X_test,y_test)
# Out:
# 0.7558839044400296

# %%
model.predict([[33,28,3,1,0,1,0,0,0,1]])
# Out:
# array([30009.84566125])

# %%
y_pred = model.predict(X_test)
# Out:
# array([ 1.66239669e+04,  1.87056397e+03,  8.83847734e+03,  2.85358407e+03,
#         1.04076755e+04,  3.07458048e+03,  2.81720022e+04,  1.21574186e+04,
#         6.22202839e+03,  3.43844989e+04,  4.94113526e+03,  1.09430833e+04,
#         9.98097307e+00,  8.63599938e+03,  1.06923605e+04,  1.05383092e+04,
#         1.40424950e+04,  3.91701336e+04,  3.43946553e+02,  6.69749204e+03,
#         2.84819909e+04,  7.53048767e+03,  1.60037115e+04,  9.80917825e+03,
#         9.42452862e+03,  2.51098502e+03,  4.29691747e+03,  1.62728237e+04,
#         1.30333443e+04,  1.26993085e+04,  2.84582867e+04,  1.24265695e+04,
#         3.56518481e+04,  1.01210012e+04,  2.99102022e+04,  3.64281440e+04,
#         3.91492211e+04,  8.98891924e+03,  1.14552107e+04,  2.41442638e+03,
#         4.57901836e+03,  8.37693079e+03, -1.46654521e+03,  7.13796724e+03,
#         9.09092131e+03,  8.45570533e+03,  3.22423439e+03,  1.52232436e+04,
# ...
